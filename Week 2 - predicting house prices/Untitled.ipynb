# %%
import graphlab

# %%
sale = graphlab.SFrame('home_data.gl/')
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\obi4m\AppData\Local\Temp\graphlab_server_1546510014.log.0
# This non-commercial license of GraphLab Create for academic use is assigned to jonathan.ifegunni@ou.edu and will expire on January 02, 2020.

# %%
sale
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
sale.show()
# Out:
# Error: Requested port is unavailable: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c2d40ce3c205> in <module>()
# ----> 1 sale.show()
#
# C:\Users\obi4m\Anaconda3\envs\gl-env\lib\site-packages\graphlab\data_structures\sframe.pyc in show(self, columns, view, x, y)
#    4950             __LOGGER__.warn("Column selection for SFrame.show is deprecated. To show only certain columns, use the sf[['column1', 'column2']] syntax or construct a new SFrame with the desired columns.")
#    4951         from ..visualization.show import show
# -> 4952         show(self, view=view, x=x, y=y)
#    4953
#    4954     def pack_columns(self, columns=None, column_prefix=None, dtype=list,
#
# C:\Users\obi4m\Anaconda3\envs\gl-env\lib\site-packages\multipledispatch\dispatcher.pyc in __call__(self, *args, **kwargs)
#     276             self._cache[types] = func
# ...
